# %%
# Importing Dataset

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
GOOGLE = pd.read_csv("GOOG.csv")
SPY = pd.read_csv("SPY.csv")

# %%
GOOGLE = GOOGLE[["Date","Close"]]
SPY = SPY[["Date","Close"]]

# %%
plt.plot(GOOGLE.Date,GOOGLE.Close)
plt.xticks(GOOGLE.Date[::100],  rotation='vertical')
# Out:
# ([<matplotlib.axis.XTick at 0x1eef1e64a70>,
#   <matplotlib.axis.XTick at 0x1eef1e645f0>,
#   <matplotlib.axis.XTick at 0x1eef1e76300>,
#   <matplotlib.axis.XTick at 0x1eeeeda5e20>,
#   <matplotlib.axis.XTick at 0x1eeeeda6720>,
#   <matplotlib.axis.XTick at 0x1eeeeda6cc0>,
#   <matplotlib.axis.XTick at 0x1eeeeda7530>,
#   <matplotlib.axis.XTick at 0x1eeeeda77d0>,
#   <matplotlib.axis.XTick at 0x1eeeeda6000>,
#   <matplotlib.axis.XTick at 0x1eeeed58230>,
#   <matplotlib.axis.XTick at 0x1eeeed58a10>,
#   <matplotlib.axis.XTick at 0x1eeeed59010>,
#   <matplotlib.axis.XTick at 0x1eeeed597f0>,
#   <matplotlib.axis.XTick at 0x1eeeeda7c80>,
#   <matplotlib.axis.XTick at 0x1eeeed58c20>,
#   <matplotlib.axis.XTick at 0x1eeeed5a360>,
#   <matplotlib.axis.XTick at 0x1eeeed5aa80>,
#   <matplotlib.axis.XTick at 0x1eeeed5b170>,
#   <matplotlib.axis.XTick at 0x1eeeed5b890>,
#   <matplotlib.axis.XTick at 0x1eeeed5afc0>,
#   <matplotlib.axis.XTick at 0x1eeeed58e30>,
#   <matplotlib.axis.XTick at 0x1eeeed5aea0>,
#   <matplotlib.axis.XTick at 0x1eeeed00b60>,
#   <matplotlib.axis.XTick at 0x1eeeed01160>,
#   <matplotlib.axis.XTick at 0x1eeeed5bfb0>,
#   <matplotlib.axis.XTick at 0x1eeeed015e0>,
#   <matplotlib.axis.XTick at 0x1eeeed5bec0>,
#   <matplotlib.axis.XTick at 0x1eeeed023f0>,
#   <matplotlib.axis.XTick at 0x1eeeed02ab0>,
#   <matplotlib.axis.XTick at 0x1eeeed03230>,
#   <matplotlib.axis.XTick at 0x1eeeed02b40>,
#   <matplotlib.axis.XTick at 0x1eeeed00290>,
#   <matplotlib.axis.XTick at 0x1eeeed03d40>,
#   <matplotlib.axis.XTick at 0x1eeeed845f0>,
#   <matplotlib.axis.XTick at 0x1eeeed84d70>,
#   <matplotlib.axis.XTick at 0x1eeeed853a0>,
#   <matplotlib.axis.XTick at 0x1eeeed021b0>],
#  [Text(0.0, 0, '2010-01-04'),
#   Text(100.0, 0, '2010-05-27'),
#   Text(200.0, 0, '2010-10-19'),
#   Text(300.0, 0, '2011-03-14'),
#   Text(400.0, 0, '2011-08-04'),
#   Text(500.0, 0, '2011-12-27'),
#   Text(600.0, 0, '2012-05-21'),
#   Text(700.0, 0, '2012-10-11'),
#   Text(800.0, 0, '2013-03-11'),
#   Text(900.0, 0, '2013-08-01'),
#   Text(1000.0, 0, '2013-12-23'),
#   Text(1100.0, 0, '2014-05-19'),
#   Text(1200.0, 0, '2014-10-09'),
#   Text(1300.0, 0, '2015-03-05'),
#   Text(1400.0, 0, '2015-07-28'),
#   Text(1500.0, 0, '2015-12-17'),
#   Text(1600.0, 0, '2016-05-12'),
#   Text(1700.0, 0, '2016-10-04'),
#   Text(1800.0, 0, '2017-02-28'),
#   Text(1900.0, 0, '2017-07-21'),
#   Text(2000.0, 0, '2017-12-12'),
#   Text(2100.0, 0, '2018-05-08'),
#   Text(2200.0, 0, '2018-09-28'),
#   Text(2300.0, 0, '2019-02-25'),
#   Text(2400.0, 0, '2019-07-18'),
#   Text(2500.0, 0, '2019-12-09'),
#   Text(2600.0, 0, '2020-05-04'),
#   Text(2700.0, 0, '2020-09-24'),
#   Text(2800.0, 0, '2021-02-18'),
#   Text(2900.0, 0, '2021-07-13'),
#   Text(3000.0, 0, '2021-12-02'),
#   Text(3100.0, 0, '2022-04-27'),
#   Text(3200.0, 0, '2022-09-20'),
#   Text(3300.0, 0, '2023-02-13'),
#   Text(3400.0, 0, '2023-07-10'),
#   Text(3500.0, 0, '2023-11-29'),
#   Text(3600.0, 0, '2024-04-24')])

# %%
plt.plot(SPY.Date,SPY.Close)
plt.xticks(SPY.Date[::100],  rotation='vertical')
# Out:
# ([<matplotlib.axis.XTick at 0x1eeed895070>,
#   <matplotlib.axis.XTick at 0x1eeed895370>,
#   <matplotlib.axis.XTick at 0x1eeecb3b200>,
#   <matplotlib.axis.XTick at 0x1eef1e80890>,
#   <matplotlib.axis.XTick at 0x1eef1e80920>,
#   <matplotlib.axis.XTick at 0x1eef1e81820>,
#   <matplotlib.axis.XTick at 0x1eeed8b5520>,
#   <matplotlib.axis.XTick at 0x1eef1e80b30>,
#   <matplotlib.axis.XTick at 0x1eef1e82510>,
#   <matplotlib.axis.XTick at 0x1eef1e82d20>,
#   <matplotlib.axis.XTick at 0x1eef1e83350>,
#   <matplotlib.axis.XTick at 0x1eef1e83c50>,
#   <matplotlib.axis.XTick at 0x1eef1e837d0>,
#   <matplotlib.axis.XTick at 0x1eef1e82180>,
#   <matplotlib.axis.XTick at 0x1eef1e833e0>,
#   <matplotlib.axis.XTick at 0x1eef1dc4dd0>,
#   <matplotlib.axis.XTick at 0x1eef1dc5400>,
#   <matplotlib.axis.XTick at 0x1eef1dc5c70>,
#   <matplotlib.axis.XTick at 0x1eef1dc59d0>,
#   <matplotlib.axis.XTick at 0x1eef1dc4590>,
#   <matplotlib.axis.XTick at 0x1eef1dc65a0>,
#   <matplotlib.axis.XTick at 0x1eef1dc6e10>,
#   <matplotlib.axis.XTick at 0x1eef1dc7530>,
#   <matplotlib.axis.XTick at 0x1eef1e829f0>,
#   <matplotlib.axis.XTick at 0x1eef1dc6b10>,
#   <matplotlib.axis.XTick at 0x1eef1dc7c20>,
#   <matplotlib.axis.XTick at 0x1eef1dc6db0>,
#   <matplotlib.axis.XTick at 0x1eef1e3cda0>,
#   <matplotlib.axis.XTick at 0x1eef1e3d610>,
#   <matplotlib.axis.XTick at 0x1eef1dc4a70>,
#   <matplotlib.axis.XTick at 0x1eef1e3c9e0>,
#   <matplotlib.axis.XTick at 0x1eef1e3e0f0>,
#   <matplotlib.axis.XTick at 0x1eef1e3e6c0>,
#   <matplotlib.axis.XTick at 0x1eef1e3ef60>,
#   <matplotlib.axis.XTick at 0x1eef1e3f650>,
#   <matplotlib.axis.XTick at 0x1eee9389ee0>,
#   <matplotlib.axis.XTick at 0x1eef1e3f1d0>],
#  [Text(0.0, 0, '2010-01-04'),
#   Text(100.0, 0, '2010-05-27'),
#   Text(200.0, 0, '2010-10-19'),
#   Text(300.0, 0, '2011-03-14'),
#   Text(400.0, 0, '2011-08-04'),
#   Text(500.0, 0, '2011-12-27'),
#   Text(600.0, 0, '2012-05-21'),
#   Text(700.0, 0, '2012-10-11'),
#   Text(800.0, 0, '2013-03-11'),
#   Text(900.0, 0, '2013-08-01'),
#   Text(1000.0, 0, '2013-12-23'),
#   Text(1100.0, 0, '2014-05-19'),
#   Text(1200.0, 0, '2014-10-09'),
#   Text(1300.0, 0, '2015-03-05'),
#   Text(1400.0, 0, '2015-07-28'),
#   Text(1500.0, 0, '2015-12-17'),
#   Text(1600.0, 0, '2016-05-12'),
#   Text(1700.0, 0, '2016-10-04'),
#   Text(1800.0, 0, '2017-02-28'),
#   Text(1900.0, 0, '2017-07-21'),
#   Text(2000.0, 0, '2017-12-12'),
#   Text(2100.0, 0, '2018-05-08'),
#   Text(2200.0, 0, '2018-09-28'),
#   Text(2300.0, 0, '2019-02-25'),
#   Text(2400.0, 0, '2019-07-18'),
#   Text(2500.0, 0, '2019-12-09'),
#   Text(2600.0, 0, '2020-05-04'),
#   Text(2700.0, 0, '2020-09-24'),
#   Text(2800.0, 0, '2021-02-18'),
#   Text(2900.0, 0, '2021-07-13'),
#   Text(3000.0, 0, '2021-12-02'),
#   Text(3100.0, 0, '2022-04-27'),
#   Text(3200.0, 0, '2022-09-20'),
#   Text(3300.0, 0, '2023-02-13'),
#   Text(3400.0, 0, '2023-07-10'),
#   Text(3500.0, 0, '2023-11-29'),
#   Text(3600.0, 0, '2024-04-24')])
