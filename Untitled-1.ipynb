# %%
# Importing Dataset
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error

# %%
GOOGLE = pd.read_csv("GOOG.csv")
SPY = pd.read_csv("SPY.csv")

# %%
GOOGLE = GOOGLE[["Date","Close"]]
SPY = SPY[["Date","Close"]]

# %%
plt.plot(GOOGLE.Date,GOOGLE.Close.apply(lambda x: math.log(x)).diff())
plt.xticks(GOOGLE.Date[::100],  rotation='vertical')
# Out:
# ([<matplotlib.axis.XTick at 0x218c60d7c50>,
#   <matplotlib.axis.XTick at 0x218ab90ff80>,
#   <matplotlib.axis.XTick at 0x218ab90e510>,
#   <matplotlib.axis.XTick at 0x218ab8fe030>,
#   <matplotlib.axis.XTick at 0x218ab920ad0>,
#   <matplotlib.axis.XTick at 0x218ab921100>,
#   <matplotlib.axis.XTick at 0x218ab9200e0>,
#   <matplotlib.axis.XTick at 0x218ab9223f0>,
#   <matplotlib.axis.XTick at 0x218ab922c60>,
#   <matplotlib.axis.XTick at 0x218ab923890>,
#   <matplotlib.axis.XTick at 0x218ab923aa0>,
#   <matplotlib.axis.XTick at 0x218ab922ed0>,
#   <matplotlib.axis.XTick at 0x218ab9348f0>,
#   <matplotlib.axis.XTick at 0x218ab9350d0>,
#   <matplotlib.axis.XTick at 0x218ab9352b0>,
#   <matplotlib.axis.XTick at 0x218ab9367b0>,
#   <matplotlib.axis.XTick at 0x218ab923620>,
#   <matplotlib.axis.XTick at 0x218ab936ae0>,
#   <matplotlib.axis.XTick at 0x218ab937950>,
#   <matplotlib.axis.XTick at 0x218ab937710>,
#   <matplotlib.axis.XTick at 0x218ab9885c0>,
#   <matplotlib.axis.XTick at 0x218ab989400>,
#   <matplotlib.axis.XTick at 0x218ab935250>,
#   <matplotlib.axis.XTick at 0x218ab989b80>,
#   <matplotlib.axis.XTick at 0x218ab98a360>,
#   <matplotlib.axis.XTick at 0x218ab98ae10>,
#   <matplotlib.axis.XTick at 0x218ab98b770>,
#   <matplotlib.axis.XTick at 0x218ab98a9f0>,
#   <matplotlib.axis.XTick at 0x218ab98be00>,
#   <matplotlib.axis.XTick at 0x218d4154770>,
#   <matplotlib.axis.XTick at 0x218d4155070>,
#   <matplotlib.axis.XTick at 0x218d4155a60>,
#   <matplotlib.axis.XTick at 0x218ab98b950>,
#   <matplotlib.axis.XTick at 0x218ce96e5d0>,
#   <matplotlib.axis.XTick at 0x218d4154b00>,
#   <matplotlib.axis.XTick at 0x218d4156720>,
#   <matplotlib.axis.XTick at 0x218d4157110>],
#  [Text(0.0, 0, '2010-01-04'),
#   Text(100.0, 0, '2010-05-27'),
#   Text(200.0, 0, '2010-10-19'),
#   Text(300.0, 0, '2011-03-14'),
#   Text(400.0, 0, '2011-08-04'),
#   Text(500.0, 0, '2011-12-27'),
#   Text(600.0, 0, '2012-05-21'),
#   Text(700.0, 0, '2012-10-11'),
#   Text(800.0, 0, '2013-03-11'),
#   Text(900.0, 0, '2013-08-01'),
#   Text(1000.0, 0, '2013-12-23'),
#   Text(1100.0, 0, '2014-05-19'),
#   Text(1200.0, 0, '2014-10-09'),
#   Text(1300.0, 0, '2015-03-05'),
#   Text(1400.0, 0, '2015-07-28'),
#   Text(1500.0, 0, '2015-12-17'),
#   Text(1600.0, 0, '2016-05-12'),
#   Text(1700.0, 0, '2016-10-04'),
#   Text(1800.0, 0, '2017-02-28'),
#   Text(1900.0, 0, '2017-07-21'),
#   Text(2000.0, 0, '2017-12-12'),
#   Text(2100.0, 0, '2018-05-08'),
#   Text(2200.0, 0, '2018-09-28'),
#   Text(2300.0, 0, '2019-02-25'),
#   Text(2400.0, 0, '2019-07-18'),
#   Text(2500.0, 0, '2019-12-09'),
#   Text(2600.0, 0, '2020-05-04'),
#   Text(2700.0, 0, '2020-09-24'),
#   Text(2800.0, 0, '2021-02-18'),
#   Text(2900.0, 0, '2021-07-13'),
#   Text(3000.0, 0, '2021-12-02'),
#   Text(3100.0, 0, '2022-04-27'),
#   Text(3200.0, 0, '2022-09-20'),
#   Text(3300.0, 0, '2023-02-13'),
#   Text(3400.0, 0, '2023-07-10'),
#   Text(3500.0, 0, '2023-11-29'),
#   Text(3600.0, 0, '2024-04-24')])

# %%
plt.plot(SPY.Date ,   SPY.Close.apply(lambda x:math.log(x)).diff()       )
plt.xticks(SPY.Date[::100],  rotation='vertical')
# Out:
# ([<matplotlib.axis.XTick at 0x218d416c5c0>,
#   <matplotlib.axis.XTick at 0x218d4176cc0>,
#   <matplotlib.axis.XTick at 0x218ab90ef30>,
#   <matplotlib.axis.XTick at 0x218d419bdd0>,
#   <matplotlib.axis.XTick at 0x218d41981d0>,
#   <matplotlib.axis.XTick at 0x218d419b800>,
#   <matplotlib.axis.XTick at 0x218d41b1460>,
#   <matplotlib.axis.XTick at 0x218d41b1d00>,
#   <matplotlib.axis.XTick at 0x218d41b2630>,
#   <matplotlib.axis.XTick at 0x218d41b2fc0>,
#   <matplotlib.axis.XTick at 0x218d41b38c0>,
#   <matplotlib.axis.XTick at 0x218d41b1fa0>,
#   <matplotlib.axis.XTick at 0x218d41b3e90>,
#   <matplotlib.axis.XTick at 0x218d4220710>,
#   <matplotlib.axis.XTick at 0x218d4221100>,
#   <matplotlib.axis.XTick at 0x218d42219a0>,
#   <matplotlib.axis.XTick at 0x218d41b0b00>,
#   <matplotlib.axis.XTick at 0x218d4221f70>,
#   <matplotlib.axis.XTick at 0x218d4222840>,
#   <matplotlib.axis.XTick at 0x218d4223110>,
#   <matplotlib.axis.XTick at 0x218d4223aa0>,
#   <matplotlib.axis.XTick at 0x218d4223500>,
#   <matplotlib.axis.XTick at 0x218d4222150>,
#   <matplotlib.axis.XTick at 0x218d423caa0>,
#   <matplotlib.axis.XTick at 0x218d423d3a0>,
#   <matplotlib.axis.XTick at 0x218d423dca0>,
#   <matplotlib.axis.XTick at 0x218d423e630>,
#   <matplotlib.axis.XTick at 0x218d423d0a0>,
#   <matplotlib.axis.XTick at 0x218d423ecf0>,
#   <matplotlib.axis.XTick at 0x218d423f620>,
#   <matplotlib.axis.XTick at 0x218d423fef0>,
#   <matplotlib.axis.XTick at 0x218d4260830>,
#   <matplotlib.axis.XTick at 0x218d423e990>,
#   <matplotlib.axis.XTick at 0x218c87cff80>,
#   <matplotlib.axis.XTick at 0x218d4261100>,
#   <matplotlib.axis.XTick at 0x218d4261a30>,
#   <matplotlib.axis.XTick at 0x218d4262360>],
#  [Text(0.0, 0, '2010-01-04'),
#   Text(100.0, 0, '2010-05-27'),
#   Text(200.0, 0, '2010-10-19'),
#   Text(300.0, 0, '2011-03-14'),
#   Text(400.0, 0, '2011-08-04'),
#   Text(500.0, 0, '2011-12-27'),
#   Text(600.0, 0, '2012-05-21'),
#   Text(700.0, 0, '2012-10-11'),
#   Text(800.0, 0, '2013-03-11'),
#   Text(900.0, 0, '2013-08-01'),
#   Text(1000.0, 0, '2013-12-23'),
#   Text(1100.0, 0, '2014-05-19'),
#   Text(1200.0, 0, '2014-10-09'),
#   Text(1300.0, 0, '2015-03-05'),
#   Text(1400.0, 0, '2015-07-28'),
#   Text(1500.0, 0, '2015-12-17'),
#   Text(1600.0, 0, '2016-05-12'),
#   Text(1700.0, 0, '2016-10-04'),
#   Text(1800.0, 0, '2017-02-28'),
#   Text(1900.0, 0, '2017-07-21'),
#   Text(2000.0, 0, '2017-12-12'),
#   Text(2100.0, 0, '2018-05-08'),
#   Text(2200.0, 0, '2018-09-28'),
#   Text(2300.0, 0, '2019-02-25'),
#   Text(2400.0, 0, '2019-07-18'),
#   Text(2500.0, 0, '2019-12-09'),
#   Text(2600.0, 0, '2020-05-04'),
#   Text(2700.0, 0, '2020-09-24'),
#   Text(2800.0, 0, '2021-02-18'),
#   Text(2900.0, 0, '2021-07-13'),
#   Text(3000.0, 0, '2021-12-02'),
#   Text(3100.0, 0, '2022-04-27'),
#   Text(3200.0, 0, '2022-09-20'),
#   Text(3300.0, 0, '2023-02-13'),
#   Text(3400.0, 0, '2023-07-10'),
#   Text(3500.0, 0, '2023-11-29'),
#   Text(3600.0, 0, '2024-04-24')])

# %%
from statsmodels.tsa.stattools import adfuller

# %%
#Augmented Dicker Fully Test Shoes that the series is stationary

statsmodels.tsa.stattools.adfuller(SPY.Close.apply(lambda x:math.log(x)).diff().dropna() )
# Out:
# (-13.12159442318257,
#  1.559124951454055e-24,
#  26,
#  3599,
#  {'1%': -3.4321682745778963,
#   '5%': -2.86234341192807,
#   '10%': -2.56719766893431},
#  -22426.13124848409)

# %%
statsmodels.tsa.stattools.adfuller(GOOGLE.Close.apply(lambda x:math.log(x)).diff().dropna()   )
# Out:
# (-14.155954999967575,
#  2.1215143206747411e-26,
#  21,
#  3604,
#  {'1%': -3.432165750199266,
#   '5%': -2.862342296861383,
#   '10%': -2.567197075308481},
#  -19020.309047852905)

# %%
#Autocorrelation to test stationarity for GOOGLE

fig, ax = plt.subplots()
plot_acf(GOOGLE.Close.apply(lambda x:math.log(x)).diff().dropna() , ax=ax)
plt.show()

# plot_acf(GOOGLE.Close.apply(lambda x:math.log(x)).diff().dropna() ,lags=200)

# %%
#Autocorrelation to test stationarity for SPY

fig, ax = plt.subplots()
plot_acf(SPY.Close.apply(lambda x:math.log(x)).diff().dropna() , ax=ax)
plt.show()

#plot_acf(SPY.Close.apply(lambda x:math.log(x)).diff().dropna() ,lags=200)

# %%
#Finding AR term (p) using PACF for GOOGLE

#fig, axes = plt.subplots()
#plot_pacf(SPY.Close.apply(lambda x:math.log(x)).diff().dropna())

plt.rcParams.update({'figure.figsize':(15,10), 'figure.dpi':120})

fig, ax = plt.subplots(2,2)
plot_pacf(GOOGLE.Close.apply(lambda x:math.log(x)).diff().dropna(),title="AR term (p) using PACF for GOOGLE",lags=10,ax=ax[0,0])
plot_pacf(SPY.Close.apply(lambda x:math.log(x)).diff().dropna(),title="#AR term (p) using PACF for SPY",lags=10,ax=ax[0,1])
plot_acf(GOOGLE.Close.apply(lambda x:math.log(x)).diff().dropna(),title=" MA(q) term using ACF for GOOGLE",lags=10,ax=ax[1,0])
plot_acf(SPY.Close.apply(lambda x:math.log(x)).diff().dropna(),title=" MA(q) term using ACF for SPY",lags=10,ax=ax[1,1])

plt.show()


#Output 

# GOOGLE - p = 1 , q = 1
# SPY - p = 2 , q = 2

# %%
#Training_the_model

from statsmodels.tsa.arima.model  import ARIMA

train_size = int(len(GOOGLE) * 0.8)
Google_train, Google_test = GOOGLE[:train_size], GOOGLE[train_size:]

model = ARIMA(Google_train.Close.apply(lambda x:math.log(x)).diff().dropna(), order=(1,0,1))
model_fit = model.fit()

print(model_fit.summary())
# Out:
# c:\Users\Siddh\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Siddh\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Siddh\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 2900
# Model:                 ARIMA(1, 0, 1)   Log Likelihood                7824.273
# Date:                Sat, 15 Jun 2024   AIC                         -15640.546
# Time:                        09:12:10   BIC                         -15616.656
# Sample:                             0   HQIC                        -15631.938
#                                - 2900
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0007      0.000      2.496      0.013       0.000       0.001
# ar.L1         -0.3281      0.234     -1.403      0.161      -0.786       0.130
# ma.L1          0.2790      0.238      1.172      0.241      -0.188       0.746
# sigma2         0.0003   2.94e-06     90.387      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             11251.78
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.25   Skew:                             0.30
# Prob(H) (two-sided):                  0.00   Kurtosis:                        12.63
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
#Forecasting test data

fc = model_fit.forecast(len(Google_test))

fc_series =    pd.Series(fc, index=Google_test.index)


plt.plot(Google_train.Close.apply(lambda x:math.log(x)).diff().dropna(), label='training')
plt.plot(Google_test.Close.apply(lambda x:math.log(x)).diff().dropna(), label='actual')
plt.plot(fc_series, label='forecast')
# Out:
# c:\Users\Siddh\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\Siddh\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
from statsmodels.tsa.arima.model  import ARIMA

train_size = int(len(GOOGLE) * 0.8)
SPY_train, SPY_test = SPY[:train_size], SPY[train_size:]

model = ARIMA(SPY_train.Close.apply(lambda x:math.log(x)).diff().dropna(), order=(2,0,2))
model_fit = model.fit()

print(model_fit.summary())
# Out:
# c:\Users\Siddh\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Siddh\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Siddh\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 2900
# Model:                 ARIMA(2, 0, 2)   Log Likelihood                9036.159
# Date:                Sat, 15 Jun 2024   AIC                         -18060.318
# Time:                        09:12:13   BIC                         -18024.483
# Sample:                             0   HQIC                        -18047.406
#                                - 2900
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0005      0.000      2.080      0.038    2.67e-05       0.001
# ar.L1          0.1021      0.240      0.426      0.670      -0.368       0.572
# ar.L2          0.2655      0.151      1.755      0.079      -0.031       0.562
# ma.L1         -0.2252      0.243     -0.927      0.354      -0.701       0.251
# ma.L2         -0.1667      0.127     -1.315      0.189      -0.415       0.082
# sigma2         0.0001   1.29e-06     89.386      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             19822.20
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.43   Skew:                            -0.87
# Prob(H) (two-sided):                  0.00   Kurtosis:                        15.69
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
fc = model_fit.forecast(len(SPY_test))

fc_series =    pd.Series(fc, index=SPY_test.index)


plt.plot(SPY_train.Close.apply(lambda x:math.log(x)).diff().dropna(), label='training')
plt.plot(SPY_test.Close.apply(lambda x:math.log(x)).diff().dropna(), label='actual')
plt.plot(fc_series, label='forecast')
# Out:
# c:\Users\Siddh\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\Siddh\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
# Output - The result is that the output values are 0, we need to investigate the error further
print(len(SPY))
# Out:
# 3627

# %%
#Using rolling window 
#https://machinelearningmastery.com/arima-for-time-series-forecasting-with-python/

X = SPY_train.Close.apply(lambda x:math.log(x)).diff().dropna()
size = int(len(X) * 0.8)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
# walk-forward validation
for t in range(len(test)):
 print(t)
 model = ARIMA(history, order=(2,0,2))
 model_fit = model.fit()
 output = model_fit.forecast()
 yhat = output[0]
 predictions.append(yhat)
 obs = test.values[t]
 history.append(obs)
 print('predicted=%f, expected=%f' % (yhat, obs))
# evaluate forecasts
rmse = math.sqrt(mean_squared_error(test, predictions))
print('Test RMSE: %.3f' % rmse)
# plot forecasts against actual outcomes
# Out:
# 0
# c:\Users\Siddh\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\Siddh\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# predicted=0.000285, expected=0.007426
# 1
# predicted=0.000096, expected=-0.005243
# 2
# predicted=0.000654, expected=0.003783
# 3
# predicted=0.000214, expected=0.006286
# 4
# predicted=0.000176, expected=0.011789
# 5
# predicted=-0.000012, expected=0.000490
# 6
# predicted=0.000469, expected=0.001572
# 7
# predicted=0.000351, expected=0.002650
# 8
# predicted=0.000314, expected=0.004829
# 9
# predicted=0.000239, expected=0.000762
# 10
# predicted=0.000414, expected=-0.005138
# 11
# predicted=0.000614, expected=0.003405
# 12
# predicted=0.000240, expected=-0.000278
# 13
# predicted=0.000441, expected=0.006743
# 14
# predicted=0.000145, expected=-0.000655
# 15
# predicted=0.000483, expected=0.000655
# 16
# predicted=0.000382, expected=-0.002450
# 17
# predicted=0.000509, expected=0.001967
# 18
# predicted=0.000315, expected=0.000862
# 19
# predicted=0.000389, expected=0.008951
# 20
# predicted=0.000069, expected=-0.002222
# 21
# predicted=0.000563, expected=-0.000616
# 22
# predicted=0.000423, expected=0.004646
# 23
# predicted=0.000226, expected=0.001567
# 24
# predicted=0.000385, expected=0.000510
# 25
# predicted=0.000407, expected=-0.007545
# 26
# predicted=0.000711, expected=-0.002161
# 27
# predicted=0.000443, expected=0.009740
# 28
# predicted=0.000015, expected=-0.004124
# 29
# predicted=0.000639, expected=-0.016841
# 30
# predicted=0.001044, expected=-0.001390
# 31
# predicted=0.000358, expected=-0.003030
# 32
# predicted=0.000508, expected=0.005011
# 33
# predicted=0.000190, expected=-0.025451
# 34
# predicted=0.001432, expected=0.009003
# 35
# predicted=-0.000135, expected=0.005840
# 36
# predicted=0.000211, expected=0.009219
# 37
# predicted=0.000074, expected=-0.006486
# 38
# predicted=0.000720, expected=-0.006634
# 39
# predicted=0.000628, expected=0.008975
# 40
# predicted=-0.000000, expected=-0.003076
# 41
# predicted=0.000574, expected=-0.012294
# 42
# predicted=0.000877, expected=0.002266
# 43
# predicted=0.000239, expected=-0.009344
# 44
# predicted=0.000779, expected=-0.006733
# 45
# predicted=0.000606, expected=0.002727
# 46
# predicted=0.000239, expected=-0.013567
# 47
# predicted=0.000945, expected=-0.002546
# 48
# predicted=0.000403, expected=0.021474
# 49
# predicted=-0.000495, expected=0.008625
# 50
# predicted=0.000149, expected=0.006482
# 51
# predicted=0.000191, expected=0.009957
# 52
# predicted=0.000049, expected=0.004578
# 53
# predicted=0.000387, expected=-0.000242
# 54
# predicted=0.000387, expected=-0.001767
# 55
# predicted=0.000386, expected=0.004118
# 56
# predicted=0.000387, expected=-0.001106
# 57
# predicted=0.000387, expected=0.000380
# 58
# predicted=0.000387, expected=0.010417
# 59
# predicted=0.000391, expected=0.002255
# 60
# predicted=0.000377, expected=0.009509
# 61
# predicted=0.000059, expected=-0.006307
# 62
# predicted=0.000710, expected=-0.001225
# 63
# predicted=0.000421, expected=-0.009856
# 64
# predicted=0.000776, expected=-0.000998
# 65
# predicted=0.000387, expected=0.003540
# 66
# predicted=0.000388, expected=0.005133
# 67
# predicted=0.000390, expected=0.009038
# 68
# predicted=0.000079, expected=0.002601
# 69
# predicted=0.000346, expected=0.007963
# 70
# predicted=0.000121, expected=-0.001139
# 71
# predicted=0.000492, expected=-0.005510
# 72
# predicted=0.000622, expected=0.001246
# 73
# predicted=0.000344, expected=0.004767
# 74
# predicted=0.000236, expected=0.002341
# 75
# predicted=0.000353, expected=0.004467
# 76
# predicted=0.000260, expected=0.000333
# 77
# predicted=0.000430, expected=-0.003230
# 78
# predicted=0.000540, expected=-0.006828
# 79
# predicted=0.000650, expected=0.003654
# 80
# predicted=0.000230, expected=-0.005570
# 81
# predicted=0.000643, expected=0.002453
# 82
# predicted=0.000297, expected=0.007125
# 83
# predicted=0.000154, expected=0.004689
# 84
# predicted=0.000280, expected=-0.004789
# 85
# predicted=0.000625, expected=0.006678
# 86
# predicted=0.000143, expected=-0.001823
# 87
# predicted=0.000512, expected=-0.002458
# 88
# predicted=0.000505, expected=-0.011001
# 89
# predicted=0.000824, expected=-0.008746
# 90
# predicted=0.000663, expected=-0.007558
# 91
# predicted=0.000620, expected=-0.030535
# 92
# predicted=0.001421, expected=0.013925
# 93
# predicted=-0.000364, expected=0.000591
# 94
# predicted=0.000465, expected=0.019430
# 95
# predicted=-0.000319, expected=-0.006835
# 96
# predicted=0.000824, expected=-0.012248
# 97
# c:\Users\Siddh\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# predicted=0.000832, expected=0.015432
# 98
# predicted=-0.000287, expected=-0.030014
# 99
# predicted=0.001738, expected=0.002638
# 100
# predicted=0.000024, expected=0.014647
# 101
# predicted=-0.000196, expected=0.011976
# 102
# predicted=0.000022, expected=-0.007692
# 103
# predicted=0.000788, expected=0.008103
# 104
# predicted=0.000020, expected=-0.000308
# 105
# predicted=0.000464, expected=-0.026023
# 106
# predicted=0.001451, expected=0.010998
# 107
# predicted=0.000377, expected=-0.003931
# 108
# predicted=0.000597, expected=0.007017
# 109
# predicted=0.000085, expected=0.012692
# 110
# predicted=-0.000106, expected=-0.000444
# 111
# predicted=0.000470, expected=-0.005864
# 112
# predicted=0.000381, expected=0.011286
# 113
# predicted=-0.000095, expected=0.012773
# 114
# predicted=-0.000064, expected=0.000772
# c:\Users\Siddh\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# predicted=0.000340, expected=-0.009540
# 386
# predicted=0.002048, expected=0.017578
# 387
# predicted=-0.002422, expected=-0.014318
# 388
# predicted=0.003601, expected=0.017257
# 389
# predicted=-0.002938, expected=0.008823
# 390
# predicted=0.000744, expected=0.008891
# 391
# predicted=-0.000207, expected=0.015960
# 392
# predicted=-0.000808, expected=-0.006547
# 393
# predicted=0.002486, expected=-0.006303
# 394
# predicted=0.000804, expected=-0.001237
# 395
# predicted=0.000293, expected=-0.000604
# 396
# predicted=0.000409, expected=-0.015320
# 397
# predicted=0.002280, expected=0.003998
# 398
# predicted=-0.001220, expected=-0.001895
# 399
# predicted=0.000978, expected=0.005470
# 400
# predicted=-0.000549, expected=0.003389
# 401
# c:\Users\Siddh\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# predicted=0.000415, expected=-0.018653
# 402
# c:\Users\Siddh\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# predicted=0.002984, expected=-0.003453
# 403
# predicted=-0.000476, expected=-0.034777
# 404
# predicted=0.004575, expected=0.010112
# 405
# predicted=-0.003605, expected=-0.010480
# 406
# predicted=0.002528, expected=0.011146
# 407
# predicted=-0.002126, expected=0.017502
# 408
# predicted=-0.000891, expected=0.022103
# 409
# predicted=-0.001171, expected=0.019315
# 410
# predicted=-0.000186, expected=-0.000228
# 411
# predicted=0.002069, expected=0.012487
# 412
# predicted=-0.000932, expected=-0.001468
# 413
# predicted=0.001798, expected=0.007401
# 414
# predicted=-0.000563, expected=-0.009748
# 415
# predicted=0.002354, expected=0.013750
# 416
# predicted=-0.002030, expected=0.012405
# 417
# predicted=0.000077, expected=-0.005393
# 418
# predicted=0.001981, expected=-0.012108
# 419
# predicted=0.001604, expected=0.004201
# 420
# predicted=-0.000896, expected=-0.006871
# 421
# predicted=0.001604, expected=0.005977
# 422
# predicted=-0.000940, expected=0.015985
# 423
# predicted=-0.001040, expected=-0.001543
# 424
# predicted=0.001788, expected=0.002781
# 425
# predicted=-0.000002, expected=-0.004437
# 426
# predicted=0.001336, expected=0.010878
# 427
# c:\Users\Siddh\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# predicted=-0.001239, expected=0.002102
# 428
# predicted=0.001071, expected=-0.000273
# 429
# c:\Users\Siddh\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# predicted=0.000588, expected=0.008581
# 430
# predicted=-0.000547, expected=-0.002057
# 431
# predicted=0.001387, expected=0.002922
# 432
# predicted=-0.000078, expected=-0.009009
# 433
# predicted=0.001859, expected=-0.000327
# 434
# predicted=-0.000228, expected=-0.001173
# 435
# predicted=0.000606, expected=-0.004487
# 436
# predicted=0.000827, expected=0.013429
# 437
# predicted=-0.001571, expected=0.001568
# 438
# predicted=0.001275, expected=0.005576
# 439
# predicted=-0.000186, expected=-0.008254
# 440
# predicted=0.001997, expected=-0.003582
# 441
# predicted=0.000255, expected=-0.001687
# 442
# predicted=0.000448, expected=0.000898
# 443
# predicted=0.000144, expected=0.003883
# 444
# predicted=0.000002, expected=0.008554
# 445
# predicted=-0.000338, expected=-0.001910
# 446
# predicted=0.001333, expected=0.001426
# 447
# predicted=0.000134, expected=0.005068
# 448
# predicted=0.000012, expected=-0.013708
# 449
# predicted=0.002519, expected=0.006864
# 450
# predicted=-0.001455, expected=0.005961
# 451
# predicted=0.000306, expected=0.014748
# 452
# predicted=-0.001032, expected=0.005682
# 453
# predicted=0.000935, expected=-0.006764
# 454
# predicted=0.001734, expected=0.000211
# 455
# predicted=0.000031, expected=0.002689
# 456
# predicted=0.000222, expected=-0.003508
# 457
# predicted=0.001055, expected=-0.007319
# 458
# predicted=0.001078, expected=0.007821
# 459
# predicted=-0.001049, expected=0.013744
# 460
# predicted=-0.000649, expected=0.000911
# 461
# c:\Users\Siddh\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# predicted=0.001307, expected=-0.003546
# 462
# predicted=0.000984, expected=0.003936
# 463
# c:\Users\Siddh\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# predicted=-0.000176, expected=-0.001562
# 464
# predicted=0.000987, expected=-0.024744
# 465
# predicted=0.003346, expected=0.008563
# 466
# predicted=-0.002443, expected=-0.020223
# 467
# predicted=0.003628, expected=0.016508
# 468
# predicted=-0.003424, expected=0.014041
# 469
# predicted=0.000062, expected=0.000786
# 470
# predicted=0.001176, expected=0.011302
# 471
# predicted=-0.000780, expected=0.003928
# 472
# predicted=0.000963, expected=0.007196
# 473
# predicted=-0.000104, expected=-0.000666
# 474
# predicted=0.001215, expected=-0.000436
# 475
# predicted=0.000508, expected=0.001614
# 476
# predicted=0.000317, expected=0.004928
# 477
# c:\Users\Siddh\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# predicted=-0.000008, expected=-0.000866
# 478
# c:\Users\Siddh\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# predicted=0.000952, expected=0.000229
# 479
# c:\Users\Siddh\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# predicted=0.000373, expected=-0.004265
# 480
# predicted=0.001050, expected=-0.001768
# 481
# predicted=0.000345, expected=-0.007721
# 482
# predicted=0.001282, expected=0.001214
# 483
# predicted=-0.000329, expected=0.010959
# 484
# predicted=-0.000807, expected=-0.024391
# 485
# predicted=0.004235, expected=-0.005166
# 486
# predicted=-0.000812, expected=0.023951
# 487
# predicted=-0.002766, expected=-0.007834
# 488
# predicted=0.003017, expected=-0.013334
# 489
# predicted=0.001410, expected=-0.012452
# 490
# predicted=0.001198, expected=0.018229
# 491
# predicted=-0.002744, expected=-0.004991
# 492
# predicted=0.002316, expected=0.014177
# 493
# predicted=-0.001885, expected=0.006205
# 494
# predicted=0.000882, expected=0.010088
# 495
# predicted=-0.000418, expected=0.001346
# 496
# predicted=0.001185, expected=0.005946
# 497
# predicted=-0.000111, expected=-0.001262
# 498
# predicted=0.001199, expected=0.003404
# 499
# predicted=-0.000014, expected=-0.014657
# 500
# predicted=0.002625, expected=-0.005122
# 501
# predicted=0.000004, expected=0.007953
# 502
# predicted=-0.000819, expected=-0.007902
# 503
# predicted=0.001889, expected=-0.005096
# 504
# predicted=0.000407, expected=0.005610
# 505
# predicted=-0.000556, expected=0.015986
# 506
# predicted=-0.001188, expected=-0.000505
# 507
# predicted=0.001612, expected=-0.002656
# 508
# predicted=0.000741, expected=0.004045
# 509
# predicted=-0.000062, expected=0.010741
# 510
# predicted=-0.000529, expected=0.014251
# 511
# predicted=-0.000505, expected=-0.000591
# 512
# predicted=0.001606, expected=0.001157
# 513
# predicted=0.000370, expected=0.004736
# 514
# predicted=0.000157, expected=0.007244
# 515
# predicted=-0.000028, expected=0.000365
# 516
# predicted=0.000995, expected=0.002959
# 517
# predicted=0.000183, expected=-0.003421
# 518
# predicted=0.001205, expected=0.010685
# 519
# predicted=-0.001068, expected=0.003337
# 520
# predicted=0.000912, expected=-0.004925
# 521
# predicted=0.001272, expected=-0.007348
# 522
# predicted=0.001122, expected=0.009418
# 523
# predicted=-0.001153, expected=-0.009175
# 524
# predicted=0.002286, expected=0.010784
# 525
# predicted=-0.001630, expected=0.002085
# 526
# predicted=0.001115, expected=-0.000216
# 527
# predicted=0.000530, expected=-0.000287
# 528
# predicted=0.000598, expected=0.006353
# 529
# predicted=-0.000301, expected=-0.006592
# 530
# predicted=0.001774, expected=0.002154
# 531
# predicted=-0.000286, expected=-0.006188
# 532
# predicted=0.001483, expected=0.000313
# 533
# predicted=-0.000084, expected=0.007954
# 534
# predicted=-0.000446, expected=0.007252
# 535
# predicted=0.000092, expected=-0.009952
# 536
# predicted=0.002204, expected=-0.008965
# 537
# predicted=0.000903, expected=-0.021474
# 538
# predicted=0.002550, expected=0.011941
# 539
# predicted=-0.002629, expected=0.015239
# 540
# predicted=-0.000555, expected=-0.002548
# 541
# predicted=0.001568, expected=-0.008653
# 542
# predicted=0.001353, expected=-0.002625
# 543
# predicted=0.000311, expected=0.010701
# 544
# predicted=-0.000988, expected=-0.000819
# 545
# predicted=0.001271, expected=0.010143
# 546
# predicted=-0.000915, expected=-0.002221
# 547
# predicted=0.001571, expected=0.001983
# 548
# predicted=0.000025, expected=0.000525
# 549
# predicted=0.000688, expected=0.001787
# 550
# predicted=0.000279, expected=-0.000881
# 551
# predicted=0.000750, expected=0.001571
# 552
# predicted=0.000223, expected=-0.003718
# 553
# predicted=0.001074, expected=0.009104
# 554
# predicted=-0.000918, expected=-0.000971
# 555
# predicted=0.001282, expected=0.000213
# 556
# predicted=0.000301, expected=-0.001493
# 557
# predicted=0.000774, expected=0.004638
# 558
# predicted=-0.000204, expected=0.001651
# 559
# predicted=0.000629, expected=0.002236
# 560
# predicted=0.000286, expected=-0.001836
# 561
# predicted=0.000905, expected=-0.005599
# 562
# predicted=0.001044, expected=-0.000332
# 563
# predicted=0.000160, expected=-0.016848
# 564
# predicted=0.002524, expected=0.014214
# 565
# predicted=-0.002541, expected=0.005332
# 566
# predicted=0.000893, expected=-0.001206
# 567
# predicted=0.000737, expected=0.005898
# 568
# predicted=-0.000240, expected=0.003546
# 569
# predicted=0.000507, expected=0.002014
# 570
# predicted=0.000468, expected=0.000538
# 571
# predicted=0.000614, expected=0.000841
# 572
# predicted=0.000457, expected=0.005521
# 573
# predicted=-0.000099, expected=0.007614
# 574
# predicted=-0.000042, expected=-0.001823
# 575
# predicted=0.001244, expected=0.003528
# 576
# predicted=-0.000047, expected=-0.008181
# 577
# predicted=0.001843, expected=0.010618
# 578
# predicted=-0.001418, expected=0.003576
# 579
# predicted=0.000894, expected=-0.003415
# Test RMSE: 0.015

# %%
predictions_series = pd.Series(predictions, index=test.index)

plt.plot(train.cumsum(), label='training')
plt.plot(test.cumsum(), label='actual')
plt.plot(predictions_series.cumsum(), label='forecast')

# %%
test.index
# Out:
# Index([2321, 2322, 2323, 2324, 2325, 2326, 2327, 2328, 2329, 2330,
#        ...
#        2891, 2892, 2893, 2894, 2895, 2896, 2897, 2898, 2899, 2900],
#       dtype='int64', length=580)
